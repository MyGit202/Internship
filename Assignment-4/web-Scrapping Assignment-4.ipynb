# %%
import selenium
from selenium import webdriver
import pandas as pd
import time
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.common.keys import Keys

# %% [raw]
# Q.1:- Scrape the details of most viewed videos on YouTube from Wikipedia:
# Url = https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos/
# You need to find following details:
# A) Rank
# B) Name
# C) Artist
# D) Upload date
# E) Views

# %%
driver = webdriver.Chrome(r'C:\Users\ajeet\Downloads\chromedriver_win32\chromedriver.exe')
time.sleep(3)
url = 'https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos/'
driver.get(url)

# %%
clk = driver.find_element_by_xpath('//span[@class="plainlinks"]//a//i')
clk.click()

# %%
clk2 = driver.find_element_by_xpath('//div[@class="mw-search-result-heading"]//a')
clk2.click()

# %%
rank = []

table = driver.find_elements_by_xpath('//table[@class="wikitable sortable jquery-tablesorter"]//tr//td')
for i in table:
    rank.append(i.text)
rank
# Out:
# ['1.',
#  '"Baby Shark Dance"[23]',
#  "Pinkfong Baby Shark - Kids' Songs & Stories",
#  '9.44',
#  'June 17, 2016',
#  '[B]',
#  '2.',
#  '"Despacito"[25]',
#  'Luis Fonsi',
#  '7.57',
#  'January 12, 2017',
#  '[C]',
#  '3.',
#  '"Johny Johny Yes Papa"[26]',
#  'LooLoo Kids',
#  '5.77',
#  'October 8, 2016',
#  '[D]',
#  '4.',
#  '"Shape of You"[27]',
#  'Ed Sheeran',
#  '5.48',
#  'January 30, 2017',
#  '[E]',
#  '5.',
#  '"See You Again"[28]',
#  'Wiz Khalifa',
#  '5.28',
#  'April 6, 2015',
#  '[F]',
#  '6.',
#  '"Bath Song"[31]',
#  'Cocomelon – Nursery Rhymes',
#  '4.55',
#  'May 2, 2018',
#  '[G]',
#  '7.',
#  '"Learning Colors – Colorful Eggs on a Farm"[32]',
#  'Miroshka TV',
#  '4.52',
#  'February 27, 2018',
#  '[H]',
#  '8.',
#  '"Masha and the Bear – Recipe for Disaster"[33]',
#  'Get Movies',
#  '4.46',
#  'January 31, 2012',
#  '[I]',
#  '9.',
#  '"Uptown Funk"[34]',
#  'Mark Ronson',
#  '4.32',
#  'November 19, 2014',
#  '[J]',
#  '10.',
# ...

# %%
ranking = []
video = []
artist = []
date = []
views =[]

for i in range(0,len(rank),6):
    ranking.append(rank[i])
    date.append(rank[i-2])
    views.append(rank[i-3])
    artist.append(rank[i-4])
    video.append(rank[i-5])

# %%
youtube = pd.DataFrame({})
youtube['ranking'] = ranking[0:30]
youtube['video'] = video[1:31]
youtube['artist'] = artist[1:31]
youtube['date'] = date[1:31]
youtube['views'] = views[1:31]
youtube
# Out:
#    ranking                                            video  \
# 0       1.                           "Baby Shark Dance"[23]
# 1       2.                                  "Despacito"[25]
# 2       3.                       "Johny Johny Yes Papa"[26]
# 3       4.                               "Shape of You"[27]
# 4       5.                              "See You Again"[28]
# 5       6.                                  "Bath Song"[31]
# 6       7.  "Learning Colors – Colorful Eggs on a Farm"[32]
# 7       8.   "Masha and the Bear – Recipe for Disaster"[33]
# 8       9.                                "Uptown Funk"[34]
# 9      10.                "Phonics Song with Two Words"[35]
# 10     11.                              "Gangnam Style"[36]
# 11     12.                             "Dame Tu Cosita"[38]
# 12     13.                                      "Sugar"[39]
# 13     14.                                      "Sorry"[40]
# 14     15.                                       "Roar"[41]
# ...

# %% [raw]
# Q.2:- Scrape the details team India’s international fixtures from bcci.tv.
# Url = https://www.bcci.tv/.
# You need to find following details:
# A) Match title (I.e. 1st ODI)
# B) Series
# C) Place
# D) Date
# E) Time
# Note: - From bcci.tv home page you have reach to the international fixture page through code.

# %%
url = 'https://www.bcci.tv/'
driver.get(url)

# %%
from selenium.webdriver.common.action_chains import ActionChains
action = ActionChains(driver)
hvr = driver.find_element_by_xpath('//div[@class="navigation__drop-down drop-down drop-down--reveal-on-hover"]')
action.move_to_element(hvr).perform()
time.sleep(2)
driver.find_element_by_xpath('//a[@class="navigation__link navigation__link--in-drop-down"]').click()

# %%
link = []

urls = driver.find_elements_by_xpath('//a[@class="js-match event-list__item event-list-item fixture  t-test fixture--long event-list-item--long"]')
                                     
for i in urls:
    link.append(i.get_attribute('href'))
link
# Out:
# ['https://www.bcci.tv/events/33758/india-v-new-zealand-2021/match/33762/1st-test?tab=overview',
#  'https://www.bcci.tv/events/33758/india-v-new-zealand-2021/match/33763/2nd-test?tab=overview',
#  'https://www.bcci.tv/events/33710/south-africa-v-india-2021-2022/match/33711/1st-test?tab=overview',
#  'https://www.bcci.tv/events/33710/south-africa-v-india-2021-2022/match/33712/2nd-test?tab=overview',
#  'https://www.bcci.tv/events/33710/south-africa-v-india-2021-2022/match/33713/3rd-test?tab=overview']

# %%
import time
title = []
series = []
place =  []
date =[]
start_time = []

for l in link:
    driver.get(l)
    time.sleep(3)
    tit =driver.find_element_by_xpath('/html/body/div[2]/div/header/div/div[1]/div/p/span')
    title.append(tit.text)
    ser = driver.find_element_by_xpath('/html/body/div[2]/div/div[2]/section[3]/div/ul/li[1]/span[2]')
    series.append(ser.text)
    plc = driver.find_element_by_xpath('/html/body/div[2]/div/div[2]/section[3]/div/ul/li[3]/span[2]')
    place.append(plc.text)
    dat = driver.find_element_by_xpath('//div[@class="mc-header-scorebox__datetime"]//strong')
    date.append(dat.text)
    tim = driver.find_element_by_xpath('//div[@class="mc-header-scorebox__datetime"]//span[1]')
    start_time.append(tim.text)
    time.sleep(4)

# %%
fixtures = pd.DataFrame({})
fixtures['title'] = title
fixtures['series'] = series
fixtures['place'] =place
fixtures['date'] = date
fixtures['start_time'] =start_time
fixtures
# Out:
#       title                          series  \
# 0  1ST TEST        India v New Zealand 2021
# 1  2ND TEST        India v New Zealand 2021
# 2  1ST TEST  South Africa v India 2021/2022
# 3  2ND TEST  South Africa v India 2021/2022
# 4  3RD TEST  South Africa v India 2021/2022
#
#                                  place                  date start_time
# 0                   Green Park, Kanpur  Thursday 25 November  09:30 IST
# 1             Wankhede Stadium, Mumbai     Friday 3 December  09:30 IST
# 2  New Wanderers Stadium, Johannesburg    Friday 17 December  13:30 IST
# 3           Supersport Park, Centurion    Sunday 26 December  13:30 IST
# 4  New Wanderers Stadium, Johannesburg      Monday 3 January  13:30 IST

# %% [raw]
# Q.3:-. Scrape the details of selenium exception from guru99.com.
# Url = https://www.guru99.com/
# You need to find following details:
# A) Name
# B) Description
# Note: - From guru99 home page you have to reach to selenium exception handling page through code.

# %%
driver = webdriver.Chrome(r'C:\Users\ajeet\Downloads\chromedriver_win32\chromedriver.exe')
url = 'https://www.guru99.com/'
driver.get(url)

# %%
action = ActionChains(driver)
hvr = driver.find_element_by_xpath('//body[1]/div[1]/div[1]/div[1]/div[1]/main[1]/div[1]/article[1]/div[1]/div[1]/div[2]/div[1]/div[1]/h4[1]/b[1]')
action.move_to_element(hvr).perform()
time.sleep(1)
driver.find_element_by_xpath('//body[1]/div[1]/div[1]/div[1]/div[1]/main[1]/div[1]/article[1]/div[1]/div[1]/div[2]/div[2]/div[1]/h4[1]').click()

# %%
name = []
description = []

table =driver.find_elements_by_xpath('//table[@class="table table-striped"]//tr//td[1]')
desc =driver.find_elements_by_xpath('//table[@class="table table-striped"]//tr//td[2]')


for i in table:
    name.append(i.text)

for j in desc:
    description.append(j.text)

# %%
exceptions = pd.DataFrame({})
exceptions['name'] = name[1:]
exceptions['description'] =description[1:]
exceptions.head()
# Out:
# Empty DataFrame
# Columns: [name, description]
# Index: []

# %% [raw]
# Q.4:- Scrape the details of State-wise GDP of India from statisticstime.com.
# Url = http://statisticstimes.com/
# You have to find following details:
# A) Rank
# B) State
# C) GSDP at current price (19-20)
# D) GSDP at current price (18-19)
# E) Share(18-19)
# F) GDP($ billion)
# Note: - From statisticstimes home page you have to reach to economy page through code.

# %%
driver = webdriver.Chrome(r'C:\Users\ajeet\Downloads\chromedriver_win32\chromedriver.exe')
url = 'http://statisticstimes.com/'
driver.get(url)

# %%
action = ActionChains(driver)
hvr = driver.find_element_by_xpath('/html/body/div[2]/div[1]/div[2]/div[2]/button')
action.move_to_element(hvr).perform()
time.sleep(2)
ads = driver.find_element_by_xpath('//*[@id="top"]/div[2]/div[2]/div/a[3]')
ads.click()
time.sleep(4)

# %%
try:
    ads1 = driver.find_element_by_css_selector('div')
    action.move_to_element(ads1).click(ads1).perform()
except:
    pass

# %%
stat = driver.find_element_by_xpath('/html/body/div[2]/div[2]/div[2]/ul/li[1]/a')
stat.click()

# %%
data = []

table = driver.find_elements_by_xpath('//div[@id="table_id_wrapper"]//tbody//tr//td')

for i in table:
    data.append(i.text)
data
# Out:
# ['1',
#  'Maharashtra',
#  '-',
#  '2,632,792',
#  '13.94%',
#  '399.921',
#  '-',
#  '2,039,074',
#  '2',
#  'Tamil Nadu',
#  '1,845,853',
#  '1,630,208',
#  '8.63%',
#  '247.629',
#  '1,312,929',
#  '1,215,307',
#  '3',
#  'Uttar Pradesh',
#  '1,687,818',
#  '1,584,764',
#  '8.39%',
#  '240.726',
#  '1,166,817',
#  '1,123,982',
#  '4',
#  'Gujarat',
#  '-',
#  '1,502,899',
#  '7.96%',
#  '228.290',
#  '-',
#  '1,186,379',
#  '5',
#  'Karnataka',
#  '1,631,977',
#  '1,493,127',
#  '7.91%',
#  '226.806',
#  '1,156,039',
#  '1,091,077',
#  '6',
#  'West Bengal',
#  '1,253,832',
#  '1,089,898',
#  '5.77%',
#  '165.556',
#  '793,223',
#  '739,525',
#  '7',
#  'Rajasthan',
#  '1,020,989',
#  '942,586',
#  '4.99%',
#  '143.179',
#  '711,627',
#  '677,428',
#  '8',
#  'Andhra Pradesh',
#  '972,782',
#  '862,957',
#  '4.57%',
#  '131.083',
#  '672,018',
#  '621,301',
#  '9',
#  'Telangana',
#  '969,604',
#  '861,031',
#  '4.56%',
#  '130.791',
#  '663,258',
#  '612,828',
#  '10',
# ...

# %%
rank = []
state_name = []
GSDP_19_20 = []
GSDP_18_19 = []
share_18_19 = []
GDP_billion = []

for j in range(1,len(data),8):
    state_name.append(data[j])

for r in range(0,len(data),8):
    rank.append(data[r])

for g in range(2, len(data),8):
    GSDP_19_20.append(data[g])

for k in range(3, len(data),8):
    GSDP_18_19.append(data[k])

for s in range(4, len(data),8):
    share_18_19.append(data[s])

for b in range(5, len(data),8):
    GDP_billion.append(data[b])

# %%
state = pd.DataFrame({})
state['Rank'] = rank
state['State'] = state_name
state['GSDP_19_20'] = GSDP_19_20
state['GSDP_18_19'] = GSDP_18_19
state['Share_18_19'] = share_18_19
state['GDP_billion'] =GDP_billion
state.head()
# Out:
#   Rank          State GSDP_19_20 GSDP_18_19 Share_18_19 GDP_billion
# 0    1    Maharashtra          -  2,632,792      13.94%     399.921
# 1    2     Tamil Nadu  1,845,853  1,630,208       8.63%     247.629
# 2    3  Uttar Pradesh  1,687,818  1,584,764       8.39%     240.726
# 3    4        Gujarat          -  1,502,899       7.96%     228.290
# 4    5      Karnataka  1,631,977  1,493,127       7.91%     226.806

# %% [raw]
# Q.5:- Scrape the details of trending repositories on Github.com.
# Url = https://github.com/
# You have to find the following details:
# A) Repository title
# B) Repository description
# C) Contributors count
# D) Language used
# Note: - From the home page you have to click on the trending option from Explore menu through code.

# %%
driver = webdriver.Chrome(r'C:\Users\ajeet\Downloads\chromedriver_win32\chromedriver.exe')
url = 'https://github.com/'
driver.get(url)

# %%
action = ActionChains(driver)
hvr = driver.find_element_by_xpath('/html/body/div[1]/header/div/div[2]/nav/ul/li[4]/details/summary')
action.move_to_element(hvr).click(hvr).click(hvr).perform()
time.sleep(3)
trend = driver.find_element_by_xpath('/html/body/div[1]/header/div/div[2]/nav/ul/li[4]/details/div/ul[2]/li[3]/a')
driver.get(trend.get_attribute('href'))

# %%
urls = []

links = driver.find_elements_by_xpath('//article[@class="Box-row"]//h1//a')

for url in links:
    urls.append(url.get_attribute('href'))
urls
# Out:
# ['https://github.com/peng-zhihui/Dummy-Robot',
#  'https://github.com/trailofbits/algo',
#  'https://github.com/Snailclimb/JavaGuide',
#  'https://github.com/louislam/uptime-kuma',
#  'https://github.com/vuejs/vue-next',
#  'https://github.com/babysor/MockingBird',
#  'https://github.com/facebook/flipper',
#  'https://github.com/fatedier/frp',
#  'https://github.com/ossrs/srs',
#  'https://github.com/vinta/awesome-python',
#  'https://github.com/yt-dlp/yt-dlp',
#  'https://github.com/ihciah/clean-dns-bpf',
#  'https://github.com/sdras/awesome-actions',
#  'https://github.com/Hack-with-Github/Awesome-Hacking',
#  'https://github.com/anncwb/vue-vben-admin',
#  'https://github.com/Python-World/Python_and_the_Web',
#  'https://github.com/wimpysworld/quickemu',
#  'https://github.com/mattiasgustavsson/dos-like',
#  'https://github.com/apache/rocketmq',
#  'https://github.com/donet5/WebFirst',
#  'https://github.com/raywenderlich/flta-materials',
#  'https://github.com/herosi/CTO',
# ...

# %%
repository_title = []
repository_description = []
contributors_count = []
language_used = []

for i in urls:
    driver.get(i)
    time.sleep(3)
    try:
        title = driver.find_element_by_xpath('//h1[@class=" d-flex flex-wrap flex-items-center break-word f3 text-normal"]')
        repository_title.append(title.text.replace('\n',''))
    except NoSuchElementException:
        repository_title.append('-')
        
    time.sleep(1)
    try:
        descrip = driver.find_element_by_xpath('/html/body/div[4]/div/main/div[2]/div/div/div[2]/div[2]/div/div[1]/div/p')
        repository_description.append(descrip.text.replace('\n',''))
    except NoSuchElementException:
        repository_description.append('-')
    
    time.sleep(1)
    try:
        count = driver.find_element_by_xpath('//h2[@class="h4 mb-3"]//a//span')
        contributors_count.append(count.text.replace('\n',''))
        
    except NoSuchElementException:
        contributors_count.append('-')
    time.sleep(1)
    try:
        lang = driver.find_element_by_xpath('//li[@class="d-inline"]//a//span')
        language_used.append(lang.text.replace('\n',''))
    except NoSuchElementException:
        language_used.append('-')

# %%
github = pd.DataFrame({})
github['repository_title'] = repository_title
github['repository_description'] = repository_description
github['contributors_count']  = contributors_count
github['language_used'] = language_used
github.head()
# Out:
#   repository_title                             repository_description  \
# 0                -                                     我的超迷你机械臂机器人项目。
# 1                -                 Set up a personal VPN in the cloud
# 2                -  「Java学习+面试指南」一份涵盖大部分 Java 程序员所需要掌握的核心知识。准备 Jav...
# 3                -                A fancy self-hosted monitoring tool
# 4                -  🖖 Vue.js is a progressive, incrementally-adopt...
#
#   contributors_count language_used
# 0                                -
# 1                  2        Python
# 2                             Java
# 3                 22    JavaScript
# 4                105    TypeScript

# %% [raw]
# Q:6:-Scrape the details of top 100 songs on billboard.com.
# Url = https://www.billboard.com/
# You have to find the following details:
# A) Song name
# B) Artist name
# C) Last week rank
# D) Peak rank
# E) Weeks on board
# Note: - From the home page you have to click on the charts option then hot 100-page link through code.

# %%
driver = webdriver.Chrome(r'C:\Users\ajeet\Downloads\chromedriver_win32\chromedriver.exe')
url = 'https://www.billboard.com/'
driver.get(url)

# %%
action = ActionChains(driver)
hov = driver.find_element_by_xpath('/html/body/div[2]/div[2]/div[2]/header/div/ul/li[1]/a')
action.move_to_element(hov).perform()
time.sleep(3)
driver.find_element_by_xpath('/html/body/div[2]/div[2]/div[2]/header/div/ul/li[1]/span/span/span/span[1]/ul/li[1]/a').click()

# %%
names = []
song_name = []
artist_name = []


name = driver.find_elements_by_xpath('//span[@class="chart-element__information"]//span')

for i in name:
    names.append(i.text)

# %%
for j in range(0,len(names),6):
    song_name.append(names[j])
    artist_name.append(names[j+1])

# %%
ranks = []

rnk = driver.find_elements_by_xpath('//div[@class="chart-element__metas chart-element__metas--large display--flex flex--y-center"]')
for r in rnk:
    ranks.append(r.text)

# %%
billboard = pd.DataFrame({})
billboard['song_name'] = song_name
billboard['artist_name'] = artist_name
billboard['ranks'] = ranks

# %%
billboard['last_week_rank'] = billboard['ranks'].str.split('\n',expand = True)[0]
billboard['peak_rank'] = billboard['ranks'].str.split('\n',expand = True)[1]
billboard['weeks_on_board'] = billboard['ranks'].str.split('\n',expand = True)[2]
billboard = billboard.drop(columns = 'ranks')
billboard.head()
# Out:
#        song_name                          artist_name last_week_rank  \
# 0    My Universe                       Coldplay x BTS              -
# 1           Stay        The Kid LAROI & Justin Bieber              1
# 2  Industry Baby              Lil Nas X & Jack Harlow              2
# 3     Way 2 Sexy  Drake Featuring Future & Young Thug              3
# 4     Fancy Like                         Walker Hayes              5
#
#   peak_rank weeks_on_board
# 0         1              1
# 1         1             12
# 2         2             10
# 3         1              4
# 4         5             15

# %% [raw]
# Q:7:- Scrape the details of Data science recruiters from naukri.com.
# Url = https://www.naukri.com/
# You have to find the following details:
# A) Name
# B) Designation
# C) Company
# D) Skills they hire for
# E) Location
# Note: - From naukri.com homepage click on the recruiters option and the on the search page type Data science and click on search. All this should be done through code

# %%
driver = webdriver.Chrome(r'C:\Users\ajeet\Downloads\chromedriver_win32\chromedriver.exe')
url = 'https://www.naukri.com/'
driver.get(url)

# %%
action  =ActionChains(driver)
hov = driver.find_element_by_xpath('//a[@title="Search Recruiters"]//div')
action.move_to_element(hov).perform()
time.sleep(3)
driver.find_element_by_xpath('/html/body/div[1]/div[1]/div/ul[1]/li[2]/div/ul/li[1]/a').click()
time.sleep(2)
driver.switch_to.window(driver.window_handles[1])
inp = driver.find_element_by_xpath('//input[@class="sugInp"]')
inp.send_keys('Data Scientist')
srch = driver.find_element_by_xpath('//button[@class="fl qsbSrch blueBtn"]')
srch.click()

# %%
links = []

for _ in range(0,10):
    nam = driver.find_elements_by_xpath('//p[@class="highlightable"]//a[1]')
    for i in nam:
        links.append(i.get_attribute('href'))

    try:
        driver.find_element_by_xpath('//div[@class="pagination"]//button[2]').click()
    except:
        driver.find_element_by_xpath('//div[@class="pagination"]//button[1]').click()
links
# Out:
# ['https://www.naukri.com/recruiters/tanushree?xid=163389458097918000&xp=1',
#  'https://www.naukri.com/recruiters/sashibhushan-2663718?xid=163389458097918000&xp=2',
#  'https://www.naukri.com/recruiters/bitapi-2057572?xid=163389458097918000&xp=3',
#  'https://www.naukri.com/recruiters/gajendrasingh?xid=163389458097918000&xp=4',
#  'https://www.naukri.com/recruiters/sadashivkulkarni-2765402?xid=163389458097918000&xp=5',
#  'https://www.naukri.com/recruiters/invelopment-2670572?xid=163389458097918000&xp=6',
#  'https://www.naukri.com/recruiters/anjalisrivastava?xid=163389458097918000&xp=7',
#  'https://www.naukri.com/recruiters/hellyvyas-2439474?xid=163389458097918000&xp=8',
#  'https://www.naukri.com/recruiters/ashishverma-2208190?xid=163389458097918000&xp=9',
#  'https://www.naukri.com/recruiters/bhuwneshari?xid=163389458097918000&xp=10',
#  'https://www.naukri.com/recruiters/Anoop.Somarajan?xid=163389458097918000&xp=11',
# ...

# %%
name = []
designation = []
company = []
skills = []
location = []

for j in links:
    driver.get(j)
    time.sleep(2)
    try:
        nam1 = driver.find_element_by_xpath('/html/body/div[2]/div[1]/div[1]/div[2]/div[2]/h1')
        name.append(nam1.text)
    except NoSuchElementException:
        name.append('-')
        
    try:
        comp = driver.find_element_by_xpath('/html/body/div[2]/div[1]/div[1]/div[2]/div[4]/a')
        company.append(comp.text)
    except NoSuchElementException:
        company.append('-')
        
    try:
        desi = driver.find_element_by_xpath('/html/body/div[2]/div[1]/div[1]/div[2]/div[3]')
        designation.append(desi.text)
    except NoSuchElementException:
        designation.append('-')
        
    try:
        ski = driver.find_element_by_xpath('/html/body/div[2]/div[1]/div[1]/div[2]/p/span')
        skills.append(ski.text)
    except NoSuchElementException:
        skills.append('-')
        
    try:
        loc = driver.find_element_by_xpath('/html/body/div[2]/div[1]/div[1]/div[2]/div[5]/a')
        location.append(loc.text)
    except NoSuchElementException:
        location.append('-')

# %%
print(len(name), len(designation),len(company), len(skills), len(location))
# Out:
# 500 500 500 500 500

# %%
naukri = pd.DataFrame({})
naukri['name'] = name
naukri['designation'] = designation
naukri['company'] = company
naukri['skills'] =skills
naukri['location'] = location
naukri.head()
# Out:
#                 name                                 designation  \
# 0          Tanushree                              Lead Recruiter
# 1      sashi bhushan                           Senior Specialist
# 2             Bitapi                    HR and Operation Manager
# 3     Gajendra Singh  Head of Recruitment - Product & Technology
# 4  Sadashiv Kulkarni                                  Company HR
#
#                                  company  \
# 0                               RecRoots
# 1                                  Wipro
# 2                                 Anvaya
# 3  A Leading of Product Start-UP Company
# 4            Digitially Insights Pvt Ltd
#
#                                               skills               location
# 0  Recruiting professionals for IT sector. Workin...                  Noida
# 1                                                  -  Bengaluru / Bangalore
# 2                                                  -  Bengaluru / Bangalore
# ...

# %% [raw]
# Q:8:- Scrape the details of Highest selling novels.
# Url = https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-grey-compare/
# You have to find the following details:
# A) Book name
# B) Author name
# C) Volumes sold
# D) Publisher
# E) Genre

# %%
driver = webdriver.Chrome(r'C:\Users\ajeet\Downloads\chromedriver_win32\chromedriver.exe')
url = 'https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-grey-compare'
driver.get(url)

# %%
tab = []

info = driver.find_elements_by_xpath('//table[@class="in-article sortable"]//tbody//tr//td')

for i in info:
    tab.append(i.text)
tab
# Out:
# ['1',
#  'Da Vinci Code,The',
#  'Brown, Dan',
#  '5,094,805',
#  'Transworld',
#  'Crime, Thriller & Adventure',
#  '2',
#  'Harry Potter and the Deathly Hallows',
#  'Rowling, J.K.',
#  '4,475,152',
#  'Bloomsbury',
#  "Children's Fiction",
#  '3',
#  "Harry Potter and the Philosopher's Stone",
#  'Rowling, J.K.',
#  '4,200,654',
#  'Bloomsbury',
#  "Children's Fiction",
#  '4',
#  'Harry Potter and the Order of the Phoenix',
#  'Rowling, J.K.',
#  '4,179,479',
#  'Bloomsbury',
#  "Children's Fiction",
#  '5',
#  'Fifty Shades of Grey',
#  'James, E. L.',
#  '3,758,936',
#  'Random House',
#  'Romance & Sagas',
#  '6',
#  'Harry Potter and the Goblet of Fire',
#  'Rowling, J.K.',
#  '3,583,215',
#  'Bloomsbury',
#  "Children's Fiction",
#  '7',
#  'Harry Potter and the Chamber of Secrets',
#  'Rowling, J.K.',
#  '3,484,047',
#  'Bloomsbury',
#  "Children's Fiction",
#  '8',
#  'Harry Potter and the Prisoner of Azkaban',
#  'Rowling, J.K.',
#  '3,377,906',
#  'Bloomsbury',
# ...

# %%
book_name = []
author_name = []
volumes_sold = []
publisher = []
genre = []

for j in range(1,len(tab),6):
    book_name.append(tab[j])
    author_name.append(tab[j+1])
    volumes_sold.append(tab[j+2])
    publisher.append(tab[j+3])
    genre.append(tab[j+4])

# %%
top_books = pd.DataFrame({})
top_books['book_name'] = book_name
top_books['author_name'] = author_name
top_books['volumes_sold'] = volumes_sold
top_books['publisher'] = publisher
top_books['genre'] = genre
top_books.head()
# Out:
#                                    book_name    author_name volumes_sold  \
# 0                          Da Vinci Code,The     Brown, Dan    5,094,805
# 1       Harry Potter and the Deathly Hallows  Rowling, J.K.    4,475,152
# 2   Harry Potter and the Philosopher's Stone  Rowling, J.K.    4,200,654
# 3  Harry Potter and the Order of the Phoenix  Rowling, J.K.    4,179,479
# 4                       Fifty Shades of Grey   James, E. L.    3,758,936
#
#       publisher                        genre
# 0    Transworld  Crime, Thriller & Adventure
# 1    Bloomsbury           Children's Fiction
# 2    Bloomsbury           Children's Fiction
# 3    Bloomsbury           Children's Fiction
# 4  Random House              Romance & Sagas

# %% [raw]
# Q:9:- Scrape the details most watched tv series of all time from imdb.com.
# Url = https://www.imdb.com/list/ls095964455/
# You have to find the following details:
# A) Name
# B) Year span
# C) Genre
# D) Run time
# E) Ratings
# F) Votes

# %%
driver = webdriver.Chrome(r'C:\Users\ajeet\Downloads\chromedriver_win32\chromedriver.exe')
url = 'https://www.imdb.com/list/ls095964455/'
driver.get(url)

# %%
name = []
year_span = []
genre = []
run_time = []
ratings = []
votes = []


nam = driver.find_elements_by_xpath('//h3[@class="lister-item-header"]//a')

for i in nam:
    name.append(i.text)
len(name)

year = driver.find_elements_by_xpath('//h3[@class="lister-item-header"]//span[2]')

for j in year:
    year_span.append(j.text)
    
gen = driver.find_elements_by_xpath('//p[@class="text-muted text-small"]//span[5]')

for g in gen:
    genre.append(g.text)

run = driver.find_elements_by_xpath('//p[@class="text-muted text-small"]//span[3]')

for r in run:
    run_time.append(r.text)
    
rat = driver.find_elements_by_xpath('//div[@class="ipl-rating-star small"]//span[2]')

for a in rat:
    ratings.append(a.text)
    

vot = driver.find_elements_by_xpath('//div[@class="lister-item mode-detail"]//div[2]//p[4]//span[2]')

for v in vot:
    votes.append(v.text)
votes
# Out:
# ['1,882,357',
#  '915,734',
#  '904,168',
#  '270,895',
#  '231,282',
#  '287,361',
#  '130,067',
#  '273,973',
#  '325,243',
#  '417,919',
#  '390,435',
#  '752,738',
#  '480,676',
#  '852,313',
#  '471,664',
#  '157,746',
#  '297,947',
#  '295,165',
#  '1,589,630',
#  '286,875',
#  '410,535',
#  '499,181',
#  '139,128',
#  '135,875',
#  '381,053',
#  '214,652',
#  '382,711',
#  '381,396',
#  '902,012',
#  '633,960',
#  '379,890',
#  '353,200',
#  '124,937',
#  '117,386',
#  '162,317',
#  '145,927',
#  '218,718',
#  '452,392',
#  '200,642',
#  '387,102',
#  '435,496',
#  '57,449',
#  '163,406',
#  '481,317',
#  '323,931',
#  '63,449',
#  '214,959',
#  '216,776',
#  '204,570',
#  '207,474',
#  '167,390',
#  '677,261',
#  '120,012',
#  '316,310',
#  '218,631',
#  '519,601',
#  '413,688',
#  '431,633',
#  '58,843',
#  '105,738',
#  '325,814',
#  '69,698',
#  '97,768',
#  '203,815',
#  '84,592',
#  '77,978',
#  '43,342',
#  '141,580',
#  '344,697',
#  '265,550',
#  '103,509',
# ...

# %%
imdb = pd.DataFrame({})
imdb['name']=name
imdb['year_span']=year_span
imdb['genre']=genre
imdb['run_time'] = run_time
imdb['ratings'] = ratings
imdb['votes'] = votes
imdb.head()
# Out:
#                name    year_span                     genre run_time ratings  \
# 0   Game of Thrones  (2011–2019)  Action, Adventure, Drama   57 min     9.2
# 1   Stranger Things     (2016– )    Drama, Fantasy, Horror   51 min     8.7
# 2  The Walking Dead  (2010–2022)   Drama, Horror, Thriller   44 min     8.2
# 3    13 Reasons Why  (2017–2020)  Drama, Mystery, Thriller   60 min     7.5
# 4           The 100  (2014–2020)    Drama, Mystery, Sci-Fi   43 min     7.6
#
#        votes
# 0  1,882,357
# 1    915,734
# 2    904,168
# 3    270,895
# 4    231,282

# %% [raw]
# Q:10:- Details of Datasets from UCI machine learning repositories.
# Url = https://archive.ics.uci.edu/
# You have to find the following details:
# A) Dataset name
# B) Data type
# C) Task
# D) Attribute type
# E) No of instances
# F) No of attribute
# G) Year
# Note: - from the home page you have to go to the Show All Dataset page through code.

# %%
driver = webdriver.Chrome(r'C:\Users\ajeet\Downloads\chromedriver_win32\chromedriver.exe')
url = 'https://archive.ics.uci.edu/ml'
driver.get(url)
time.sleep(2)
driver.find_element_by_xpath('/html/body/table[2]/tbody/tr/td/span/b/a').click()

# %%
attribute = []
instances = []
attribute = []
year = []
links=[]

name = driver.find_elements_by_xpath('//td[@valign="top"]//tbody//tr')

for i in name:
    links.append(i.text)
links
# Out:
# ['Browse Through:',
#  'Default Task',
#  'Classification (442)\nRegression (137)\nClustering (117)\nOther (56)',
#  'Attribute Type',
#  'Categorical (38)\nNumerical (396)\nMixed (55)',
#  'Data Type',
#  'Multivariate (456)\nUnivariate (27)\nSequential (57)\nTime-Series (121)\nText (66)\nDomain-Theory (23)\nOther (21)',
#  'Area',
#  'Life Sciences (138)\nPhysical Sciences (57)\nCS / Engineering (215)\nSocial Sciences (38)\nBusiness (44)\nGame (11)\nOther (80)',
#  '# Attributes',
#  'Less than 10 (151)\n10 to 100 (266)\nGreater than 100 (106)',
#  '# Instances',
#  'Less than 100 (36)\n100 to 1000 (199)\nGreater than 1000 (318)',
#  'Format Type',
#  'Matrix (411)\nNon-Matrix (177)',
#  '588 Data Sets\nTable View  List View',
#  'Name\nData Types\nDefault Task\nAttribute Types\n# Instances\n# Attributes\nYear',
#  '  Abalone\nMultivariate \nClassification \nCategorical, Integer, Real \n4177 \n8 \n1995 ',
#  '  Abalone',
# ...

# %%
element = []
for i in range(17,len(links),2):
    element.append(links[i])
element
# Out:
# ['  Abalone\nMultivariate \nClassification \nCategorical, Integer, Real \n4177 \n8 \n1995 ',
#  '  Adult\nMultivariate \nClassification \nCategorical, Integer \n48842 \n14 \n1996 ',
#  '  Annealing\nMultivariate \nClassification \nCategorical, Integer, Real \n798 \n38 \n ',
#  '  Anonymous Microsoft Web Data\n  Recommender-Systems \nCategorical \n37711 \n294 \n1998 ',
#  '  Arrhythmia\nMultivariate \nClassification \nCategorical, Integer, Real \n452 \n279 \n1998 ',
#  '  Artificial Characters\nMultivariate \nClassification \nCategorical, Integer, Real \n6000 \n7 \n1992 ',
#  '  Audiology (Original)\nMultivariate \nClassification \nCategorical \n226 \n  1987 ',
#  '  Audiology (Standardized)\nMultivariate \nClassification \nCategorical \n226 \n69 \n1992 ',
#  '  Auto MPG\nMultivariate \nRegression \nCategorical, Real \n398 \n8 \n1993 ',
#  '  Automobile\nMultivariate \nRegression \nCategorical, Integer, Real \n205 \n26 \n1987 ',
# ...

# %%
dataset = pd.DataFrame({})
dataset['element'] = element
dataset['name'] =  dataset['element'].str.split('\n',expand = True)[0]
dataset['data_type'] = dataset['element'].str.split('\n',expand = True)[1]
dataset['task'] = dataset['element'].str.split('\n',expand = True)[2]
dataset['attribute_type'] = dataset['element'].str.split('\n',expand = True)[3]
dataset['instance'] = dataset['element'].str.split('\n',expand = True)[4]
dataset['attribute'] = dataset['element'].str.split('\n',expand = True)[5]
dataset['year'] = dataset['element'].str.split('\n',expand = True)[6]
dataset = dataset.drop(columns = 'element')
dataset.head()
# Out:
#                              name               data_type             task  \
# 0                         Abalone           Multivariate   Classification
# 1                           Adult           Multivariate   Classification
# 2                       Annealing           Multivariate   Classification
# 3    Anonymous Microsoft Web Data    Recommender-Systems      Categorical
# 4                      Arrhythmia           Multivariate   Classification
#
#                 attribute_type instance attribute   year
# 0  Categorical, Integer, Real     4177         8   1995
# 1        Categorical, Integer    48842        14   1996
# 2  Categorical, Integer, Real      798        38
# 3                       37711      294      1998    None
# 4  Categorical, Integer, Real      452       279   1998
